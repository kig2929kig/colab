# %% [markdown]
# <a href="https://colab.research.google.com/github/kig2929kig/colab/blob/main/artTurtle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 작품명 : 사춘기 거북이

# %% [markdown]
# https://opensea.io/assets/ethereum/0x495f947276749ce646f68ac8c248420045cb7b5e/48004598603185683346987757871720396655812825897480576681176319487284982317057

# %%
#!pip3 install ColabTurtle
import ColabTurtle.Turtle as turtle
import random
print(turtle.DEFAULT_WINDOW_SIZE)
turtle.initializeTurtle()
count = 1
while count <= 360 :
  turtle.left(1)
  turtle.color((random.randint(0,255),random.randint(0,255),random.randint(0,255)))
  turtle.forward(random.randint(800,1000))
  if 800 <= turtle.getx() or  turtle.getx() <= 0 or \
  500 <= turtle.gety() or turtle.gety() <=0:
    turtle.goto(400,250)
  count= count + 1
# Out:
# (800, 500)
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
# ...
